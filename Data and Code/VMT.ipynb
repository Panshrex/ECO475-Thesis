# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 500)

# %%
vmt = pd.read_excel("/Data/VMT Per Capita By State.xlsx") 
#vmt.set_index("Year", drop = True, inplace = True)
vmt
# Out:
#               Year   1981   1982  1983   1984   1985   1986   1987   1988  \
# 0          Alabama   7107   7607  7888   8340   8832   8518   9324   9862
# 1           Alaska   6964   7704  6881   7490   7538   7349   7236   7301
# 2          Arizona   6954   7059  6923   6824   6778   6852   9232   9688
# 3         Arkansas   7202   7249  7235   7164   7354   7528   7816   8203
# 4       California   6584   6849  7202   7605   7851   7930   8147   8487
# 5         Colorado   7727   7961  7929   8249   8148   8150   8272   8481
# 6      Connecticut   6189   6415  6524   6628   6995   7465   7699   7965
# 7         Delaware   7480   7664  8076   8395   8681   9175   9554   9883
# 8    Dist. of Col.   5193   5331  4903   5077   5076   5152   5287   5405
# 9          Florida   7470   7592  7607   7742   7758   7494   7741   8574
# 10         Georgia   8054   8634  8526   8652   9008   9340   9712   9858
# 11          Hawaii   5987   6085  5798   6328   6502   6626   6758   6869
# ...

# %%
vmt_long = pd.melt(vmt, id_vars = "Year")
vmt_long.columns = ["State", "Year", "VMT per Capita"]
vmt_long = vmt_long[~(vmt_long["State"] == "US Average")]
vmt_long
# Out:
#               State  Year  VMT per Capita
# 0           Alabama  1981            7107
# 1            Alaska  1981            6964
# 2           Arizona  1981            6954
# 3          Arkansas  1981            7202
# 4        California  1981            6584
# ...             ...   ...             ...
# 1918       Virginia  2017           10072
# 1919     Washington  2017            8272
# 1920  West Virginia  2017           10496
# 1921      Wisconsin  2017           11278
# 1922        Wyoming  2017           16901
#
# [1887 rows x 3 columns]

# %%
vmt_long.to_excel("VMT Long.xlsx", index = False)
files.download("VMT Long.xlsx")
