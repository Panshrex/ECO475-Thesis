# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 500)

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fedpol = pd.read_csv("/content/drive/MyDrive/University Shit /ECO475/Data/countypres_2000-2020.csv")
fedpol = fedpol[fedpol["year"].isin([2016, 2020])]
fedpol.reset_index(inplace = True, drop = True)
fedpol
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2016  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2016  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2016  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2016  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 4      2016  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 31562  2020  WYOMING       WY    WASHAKIE      56043.0  US PRESIDENT
# 31563  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 31564  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 31565  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 31566  2020  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# ...

# %%
grouped = fedpol.groupby(["year", "state", "county_name", "party"])

cont = []

for group, frame in grouped:

  frame_prime = frame.head(1)

  frame_prime["candidatevotes"] = [frame["candidatevotes"].sum()]
  frame_prime["mode"] = ["TOTAL"]

  cont.append(frame_prime)

finished = pd.concat(cont)
# Out:
# <ipython-input-13-54b7b5751f6c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_prime["candidatevotes"] = [frame["candidatevotes"].sum()]
# <ipython-input-13-54b7b5751f6c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_prime["mode"] = ["TOTAL"]

# %%
finished.to_csv("county elections 2019-2022 grouped.csv")
files.download("county elections 2019-2022 grouped.csv")
